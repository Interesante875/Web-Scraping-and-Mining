# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install html5lib
# !pip install requests

import requests
from bs4 import BeautifulSoup
import time
import re
import json
import string
import pandas as pd
import csv
import math
import threading
import os
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.2.6)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
## General functions

def create_project_dir(directory):
    if not os.path.exists(directory):
        print(f'Creating project {directory}')
        os.makedirs(directory)

def create_data_files(project_name, base_url):
    queue = project_name + '/queue.txt'
    crawled = project_name + '/crawled.txt'
    if not os.path.isfile(queue):
        write_file(queue, base_url)
    if not os.path.isfile(crawled):
        write_file(crawled, '')

def write_file(path, data):
    with open(path, 'w') as f:
        f.write(data)
        f.close()

# Add data onto an existing file
def append_to_file(path, data):
    with open(path, 'a') as file:
        file.write(data + '\n')

# Delete the contents of a file
def delete_file_contents(path):
    with open(path, 'w'):
        pass

# Read a file and convert each line to set items
def file_to_set(file_name):
    results = set()
    with open(file_name, 'rt') as f:
        for line in f:
            results.add(line.replace('\n', ''))
    return results


# Iterate through a set, each item will be a line in a file
def set_to_file(links, file_name):
    with open( file_name,"w") as f:
        for l in sorted(links):
            f.write(l+"\n")

# %%
from html.parser import HTMLParser
from urllib import parse

class LinkFinder(HTMLParser):
    def __init__(self, base_url, page_url):
        super().__init__()
        self.base_url = base_url
        self.page_url = page_url
        self.links = set()

    def handle_starttag(self, tag, attrs):
        if tag == 'a':
            for (attribute, value) in attrs:
                if attribute == 'href':
                    url = parse.urljoin(self.base_url, value)
                    self.links.add(url)

    def page_links(self):
        return self.links

    def error(self, message):
        pass

# %%
from urllib.request import urlopen

class Spider:

    project_name = ''
    base_url = ''
    domain_name = ''
    queue_file = ''
    crawled_file = ''
    queue = set()
    crawled = set()

    def __init__(self, project_name, base_url, domain_name):
        Spider.project_name = project_name
        Spider.base_url = base_url
        Spider.domain_name = domain_name
        Spider.queue_file = Spider.project_name + '/queue.txt'
        Spider.crawled_file = Spider.project_name + '/crawled.txt'
        self.boot()
        self.crawl_page('First spider', Spider.base_url)

    # Creates directory and files for project on first run and starts the spider
    @staticmethod
    def boot():
        create_project_dir(Spider.project_name)
        create_data_files(Spider.project_name, Spider.base_url)
        Spider.queue = file_to_set(Spider.queue_file)
        Spider.crawled = file_to_set(Spider.crawled_file)

    # Updates user display, fills queue and updates files
    @staticmethod
    def crawl_page(thread_name, page_url):
        if page_url not in Spider.crawled:
            print(thread_name + ' now crawling ' + page_url)
            print('Queue ' + str(len(Spider.queue)) + ' | Crawled  ' + str(len(Spider.crawled)))
            Spider.add_links_to_queue(Spider.gather_links(page_url))
            Spider.queue.remove(page_url)
            Spider.crawled.add(page_url)
            Spider.update_files()

    # Converts raw response data into readable information and checks for proper html formatting
    @staticmethod
    def gather_links(page_url):
        html_string = ''
        try:
            response = urlopen(page_url)
            if 'text/html' in response.getheader('Content-Type'):
                html_bytes = response.read()
                html_string = html_bytes.decode("utf-8")
            finder = LinkFinder(Spider.base_url, page_url)
            finder.feed(html_string)
        except Exception as e:
            print(str(e))
            return set()
        return finder.page_links()

    # Saves queue data to project files
    @staticmethod
    def add_links_to_queue(links):
        for url in links:
            if (url in Spider.queue) or (url in Spider.crawled):
                continue
            if Spider.domain_name != get_domain_name(url):
                continue
            Spider.queue.add(url)

    @staticmethod
    def update_files():
        set_to_file(Spider.queue, Spider.queue_file)
        set_to_file(Spider.crawled, Spider.crawled_file)

# %%
from urllib.parse import urlparse

# Get domain name (example.com)
def get_domain_name(url):
    try:
        results = get_sub_domain_name(url).split('.')
        return results[-2] + '.' + results[-1]
    except:
        return ''

# Get sub domain name (name.example.com)
def get_sub_domain_name(url):
    try:
        return urlparse(url).netloc
    except:
        return ''

# %%
from queue import *

PROJECT_NAME = 'BernamaEn'
HOMEPAGE = 'https://www.bernama.com/en/'
DOMAIN_NAME = get_domain_name(HOMEPAGE)
QUEUE_FILE = PROJECT_NAME + '/queue.txt'
CRAWLED_FILE = PROJECT_NAME + '/crawled.txt'
NUMBER_OF_THREADS = 8
queue = Queue()
Spider(PROJECT_NAME, HOMEPAGE, DOMAIN_NAME)

# Create worker threads (will die when main exits)
def create_workers():
    for _ in range(NUMBER_OF_THREADS):
        t = threading.Thread(target=work)
        t.daemon = True
        t.start()


# Do the next job in the queue
def work():
    while True:
        url = queue.get()
        Spider.crawl_page(threading.current_thread().name, url)
        queue.task_done()


# Each queued link is a new job
def create_jobs():
    for link in file_to_set(QUEUE_FILE):
        queue.put(link)
    queue.join()
    crawl()


# Check if there are items in the queue, if so crawl them
def crawl():
    queued_links = file_to_set(QUEUE_FILE)
    if len(queued_links) > 0:
        print(str(len(queued_links)) + ' links in the queue')
        create_jobs()


create_workers()
crawl()
# Out:
# Creating project BernamaEn
# First spider now crawling https://www.bernama.com/en/
# Queue 1 | Crawled  0
# 127 links in the queue
# Thread-23 now crawling https://www.bernama.com/en/world/news.php?id=2022540
# Queue 127 | Crawled  1
# Thread-25 now crawling https://www.bernama.com/misc/contactus/index.php
# Queue 127 | Crawled  1
# Thread-22 now crawling https://www.bernama.com/radio/
# Queue 127 | Crawled  1
# Thread-19 now crawling https://www.bernama.com/en/news.php?id=2022486
# Queue 127 | Crawled  1
# Thread-26 now crawling https://www.bernama.com/corporate/services.phpThread-21 now crawling https://www.bernama.com/en/crime_courts/news.php?id=2022568
# Queue 127 | Crawled  1
# Thread-24 now crawling https://www.bernama.com/en/search.php
# Queue 127 | Crawled  1
#
# Queue 127 | Crawled  1
# Thread-20 now crawling https://www.bernama.com/en/videos/
# Queue 127 | Crawled  1
# Thread-25 now crawling https://www.bernama.com/bm/index.php
# Queue 126 | Crawled  2
# Thread-19 now crawling https://www.bernama.com/en/business/news.php?id=2022520
# Queue 137 | Crawled  3
# Thread-26 now crawling https://www.bernama.com/en/general/
# Queue 155 | Crawled  4
# Thread-24 now crawling https://www.bernama.com/en/region/index.php?s=2
# Queue 164 | Crawled  5
# Thread-23 now crawling https://www.bernama.com/en/thoughts/news.php?id=2018973
# Queue 171 | Crawled  6
# Thread-21 now crawling https://www.bernama.com/bm/oku.php
# Queue 173 | Crawled  7
# Thread-20 now crawling https://www.bernama.com/en/region/index.php?s=1
# Queue 250 | Crawled  8
# Thread-19 now crawling https://www.bernama.com/en/region/index.php?s=6
# Queue 249 | Crawled  9
# Thread-23 now crawling https://www.bernama.com/en/politics/news.php?id=2022485
# Queue 264 | Crawled  10
# Thread-24 now crawling https://www.bernama.com/en/news.php?id=2022511
# Queue 278 | Crawled  11
# Thread-26 now crawling https://www.bernama.com/en/region/index.php?s=4
# Queue 291 | Crawled  12
# Thread-22 now crawling https://www.bernama.com/en/sports/
# Queue 317 | Crawled  13
# Thread-24 now crawling https://www.bernama.com/en/news.php?id=2022535
# Queue 324 | Crawled  14
# Thread-21 now crawling https://www.bernama.com/tv/index.php
# Queue 369 | Crawled  15
# Thread-23 now crawling https://www.bernama.com/en/business/news.php?id=2022518
# Queue 376 | Crawled  16
# Thread-24 now crawling https://www.bernama.com/en/general/news_covid-19.php?id=2022282
# Queue 383 | Crawled  17
# Thread-20 now crawling https://www.bernama.com/en/politics/news.php?id=2022484
# Queue 393 | Crawled  18
# Thread-19 now crawling https://www.bernama.com/ar/index.php
# Queue 408 | Crawled  19
# Thread-22 now crawling https://www.bernama.com/en/general/news_covid-19.php?id=2022385
# Queue 420 | Crawled  20
# Thread-23 now crawling https://www.bernama.com/en/world/index.php
# Queue 420 | Crawled  21
# Thread-21 now crawling https://www.bernama.com/en/features/news.php?id=2021167
# Queue 428 | Crawled  22
# Thread-26 now crawling https://www.bernama.com/en/world/news.php?id=2022492
# Queue 437 | Crawled  23
# Thread-25 now crawling https://www.bernama.com/en/business/pemerkasa.php
# Queue 494 | Crawled  24
# Thread-24 now crawling https://www.bernama.com/en/copyrights.php#a
# Queue 493 | Crawled  25
# Thread-20 now crawling https://www.bernama.com/en/news.php?id=2022482
# Queue 496 | Crawled  26
# Thread-21 now crawling https://www.bernama.com/en/market/index.php
# Queue 505 | Crawled  27
# Thread-26 now crawling https://www.bernama.com/en/crime_courts/index.php
# Queue 519 | Crawled  29
# Thread-23 now crawling https://www.bernama.com/en/politics/index.php
# Queue 519 | Crawled  29
# Thread-22 now crawling https://www.bernama.com/en/general/news_covid-19.php?id=2022283
# Queue 518 | Crawled  30
# Thread-24 now crawling https://www.bernama.com/tv/
# Queue 517 | Crawled  31
# Thread-20 now crawling http://sarawaktok.bernama.com/index.php
# Queue 521 | Crawled  32
# Thread-20 now crawling http://energy.bernama.com
# Queue 543 | Crawled  33
# Thread-21 now crawling https://www.bernama.com/es/index.php
# Queue 553 | Crawled  34
# Thread-24 now crawling https://www.bernama.com/tam/index.php
# Queue 552 | Crawled  35
# Thread-23 now crawling https://www.bernama.com/en/#submenu1
# Queue 553 | Crawled  36
# Thread-20 now crawling https://www.bernama.com/en/region/index.php?s=5
# Queue 571 | Crawled  37
# Thread-26 now crawling https://www.bernama.com/radio/index.php
# Queue 576 | Crawled  38
# Thread-22 now crawling http://prn.bernama.com/melaka/news.php?id=2022484
# Queue 575 | Crawled  39
# Thread-19 now crawling https://www.bernama.com/en/features/index.php
# Queue 614 | Crawled  40
# Thread-21 now crawling https://www.bernama.com/en/general/news_covid-19.php?id=2022486
# Queue 653 | Crawled  41
# Thread-22 now crawling https://www.bernama.com/en/sports/news.php?id=2022317
# Queue 664 | Crawled  42
# Thread-26 now crawling https://www.bernama.com/man/index.php
# Queue 667 | Crawled  43
# Thread-19 now crawling https://www.bernama.com/en/general/covid-19.php
# Queue 672 | Crawled  44
# Thread-20 now crawling https://www.bernama.com/en/press/index.php
# Queue 681 | Crawled  45
# Thread-21 now crawling https://www.bernama.com/en/world/news.php?id=2022412
# Queue 681 | Crawled  46
# Thread-20 now crawling http://rukunnegara.bernama.com/pidato
# Queue 689 | Crawled  47
# Thread-20 now crawling https://www.bernama.com/en/#submenu0
# Queue 694 | Crawled  48
# Thread-24 now crawling https://www.bernama.com/en/features/
# Queue 737 | Crawled  49
# Thread-22 now crawling https://www.bernama.com/en/infographics/index.php
# Queue 742 | Crawled  50
# Thread-23 now crawling https://www.bernama.com/en/world/news.php?id=2022570
# Queue 741 | Crawled  51
# Thread-19 now crawling https://www.bernama.com/en/politics/news.php?id=2022450
# Queue 760 | Crawled  52
# Thread-21 now crawling https://www.bernama.com/en/#submenu2
# Queue 770 | Crawled  53
# Thread-22 now crawling https://www.bernama.com/en/business/index.php
# Queue 778 | Crawled  54
# Thread-26 now crawling https://www.bernama.com/en/market/
# Queue 820 | Crawled  55
# Thread-23 now crawling http://prn.bernama.com/melaka/news.php?id=2022371
# Queue 823 | Crawled  56
# Thread-19 now crawling https://www.bernama.com/en/general/news.php?id=2022443
# Queue 829 | Crawled  57
# Thread-24 now crawling https://www.bernama.com/en/world/news.php?id=2022429
# Queue 828 | Crawled  58
# Thread-23 now crawling https://www.bernama.com/en/archive.php
# Queue 832 | Crawled  59
# Thread-26 now crawling https://www.bernama.com/en/features/news.php?id=2021550
# Queue 831 | Crawled  60
# Thread-22 now crawling https://www.bernama.com/en/#topstory
# Queue 837 | Crawled  61
# Thread-25 now crawling https://www.bernama.com/en/thoughts/
# Queue 855 | Crawled  62
# Thread-19 now crawling https://www.bernama.com/en/#submenu3
# Queue 856 | Crawled  63
# Thread-24 now crawling https://www.bernama.com/en/general/news.php?id=2022469
# Queue 859 | Crawled  64
# Thread-25 now crawling https://www.bernama.com/en/crime_courts/news.php?id=2022414
# Queue 885 | Crawled  65
# Thread-23 now crawling https://www.bernama.com/en/crime_courts/news.php?id=2022569
# Queue 901 | Crawled  66
# Thread-26 now crawling https://www.bernama.com/en/thoughts/news.php?id=2021871
# Queue 907 | Crawled  67
# Thread-25 now crawling https://www.bernama.com/en/world/
# Queue 907 | Crawled  68
# Thread-23 now crawling https://www.bernama.com/en/infographics/
# Queue 909 | Crawled  69
# Thread-20 now crawling https://www.bernama.com/en/world/news.php?id=2022537
# Queue 908 | Crawled  70
# Thread-24 now crawling https://www.bernama.com/en/business/news.php?id=2022512
# Queue 909 | Crawled  71
# Thread-26 now crawling https://www.bernama.com/en/sports/index.php
# Queue 912 | Crawled  72
# Thread-25 now crawling https://www.bernama.com/en/sports/news.php?id=2022343
# Queue 911 | Crawled  73
# Thread-20 now crawling https://www.bernama.com/en/crime_courts/news.php?id=2022380
# Queue 914 | Crawled  74
# Thread-24 now crawling https://www.bernama.com/en/general/news.php?id=2022526
# Queue 916 | Crawled  75
# Thread-26 now crawling http://prn.bernama.com/melaka/news.php?id=2022450
# Queue 915 | Crawled  76
# Thread-21 now crawling https://www.bernama.com/en/general/index.php
# Queue 914 | Crawled  77
# Thread-26 now crawling https://www.bernama.com/en/features/news.php?id=2022455
# Queue 917 | Crawled  78
# Thread-25 now crawling https://www.bernama.com/en/sports/news.php?id=2022533
# Queue 919 | Crawled  79
# Thread-23 now crawling https://www.bernama.com/en/#carouselExample
# Queue 918 | Crawled  80
# Thread-26 now crawling https://www.bernama.com/en/thoughts/news.php?id=2020795
# Queue 923 | Crawled  81
# Thread-19 now crawling https://www.bernama.com/en/business/
# Queue 922 | Crawled  82
# Thread-20 now crawling https://www.bernama.com/en/sports/news.php?id=2022334
# Queue 924 | Crawled  83
# Thread-24 now crawling http://prn.bernama.com/melaka/index.php
# Queue 930 | Crawled  85
# Thread-25 now crawling https://www.bernama.com/en/general/news.php?id=2022444
# Queue 930 | Crawled  85
# Thread-26 now crawling https://www.bernama.com/en/meta/
# Queue 929 | Crawled  86
# Thread-22 now crawling https://www.bernama.com/en/world/news.php?id=2022478
# Queue 928 | Crawled  87
# Thread-21 now crawling https://www.bernama.com/en/copyrights.php#b
# Queue 927 | Crawled  88
# Thread-20 now crawling https://www.bernama.com/en/b_focus/
# Queue 934 | Crawled  89
# Thread-22 now crawling https://www.bernama.com/en/business/news.php?id=2022507Thread-25 now crawling https://www.bernama.com/en/general/news_covid-19.php?id=2022469
# Queue 941 | Crawled  91
#
# Queue 941 | Crawled  91
# Thread-21 now crawling https://www.bernama.com/en/region/index.php?s=3
# Queue 940 | Crawled  92
# Thread-20 now crawling https://www.bernama.com/en/meta/index.php
# Queue 957 | Crawled  94
# Thread-26 now crawling http://webinar.bernama.com
# Queue 957 | Crawled  94
# Thread-23 now crawling https://www.bernama.com/en/general/news.php?id=2022499
# Queue 956 | Crawled  95
# Thread-19 now crawling https://images.bernama.com
# Queue 955 | Crawled  96
# Thread-22 now crawling https://www.bernama.com/en/b_focus/index.php
# Queue 954 | Crawled  97
# Thread-26 now crawling https://www.bernama.com/en/politics/news.php?id=2022532
# Queue 954 | Crawled  98
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)>
# Thread-19 now crawling https://www.bernama.com/en/thoughts/index.php
# Queue 953 | Crawled  99
# Thread-25 now crawling http://mapo.bernama.com
# Queue 952 | Crawled  100
# Thread-19 now crawling http://health.bernama.com
# Queue 951 | Crawled  101
# Thread-21 now crawling https://www.bernama.com/en/business/news.php?id=2022553
# Queue 966 | Crawled  102
# Thread-25 now crawling https://www.bernama.com/en/news.php?id=2022480
# Queue 995 | Crawled  103
# Thread-22 now crawling https://kerjaya.bernama.com
# Queue 994 | Crawled  104
# Thread-23 now crawling https://www.bernama.com/en/#submenu_crime
# Queue 994 | Crawled  105
# Thread-26 now crawling http://prn.bernama.com/melaka/news.php?id=2022310
# Queue 1001 | Crawled  106
# Thread-19 now crawling https://www.bernama.com/en/videos/index.php
# Queue 1018 | Crawled  107
# Thread-20 now crawling https://www.bernama.com/misc/sewa/index.htmThread-24 now crawling https://www.bernama.com/en/politics/
#
# Queue 1027 | Crawled  109
# Queue 1027 | Crawled  109
# Thread-22 now crawling https://www.bernama.com/en/thoughts/news.php?id=2017537
# Queue 1028 | Crawled  110
# Thread-21 now crawling https://www.bernama.com/en/rssfeed.php
# Queue 1027 | Crawled  111
# Thread-22 now crawling https://www.bernama.com/corporate/index.php
# Queue 1039 | Crawled  113
# Thread-26 now crawling https://www.bernama.com/en/business/news.php?id=2022461
# Queue 1039 | Crawled  113
# Thread-21 now crawling https://www.bernama.com/en/index.php
# Queue 1038 | Crawled  114
# Thread-25 now crawling https://www.bernama.com/en/general/news.php?id=2022536
# Queue 1047 | Crawled  115
# Thread-24 now crawling https://www.bernama.com/en/crime_courts/
# Queue 1046 | Crawled  116
# Thread-22 now crawling https://www.bernama.com/en/features/news.php?id=2021959
# Queue 1045 | Crawled  117
# Thread-26 now crawling https://www.bernama.com/en/copyrights.php#c
# Queue 1045 | Crawled  118
# Thread-25 now crawling https://www.bernama.com/en/#submenu4
# Queue 1044 | Crawled  119
# Thread-24 now crawling https://www.bernama.com/en/press/
# Queue 1043 | Crawled  120
# 'utf-8' codec can't decode byte 0xb7 in position 77482: invalid start byte
# 1041 links in the queue
# Thread-21 now crawling https://www.bernama.com/en/index.php#3Thread-19 now crawling https://www.bernama.com/en/#home
# Queue 1041 | Crawled  128
# Thread-22 now crawling https://www.bernama.com/en/listbm.php
# Queue 1041 | Crawled  128
# Thread-23 now crawling https://www.bernama.com/en/video.php
# Queue 1041 | Crawled  128
# Thread-24 now crawling https://www.bernama.com/en/news.php?id=2021725
# Queue 1041 | Crawled  128
# Thread-20 now crawling https://www.bernama.com/en/search.php?terms=+cluster.+
# Queue 1041 | Crawled  128
# Thread-25 now crawling https://www.bernama.com/corporate/orgchart.php
# Queue 1041 | Crawled  128
# Thread-26 now crawling https://www.bernama.com/en/?v=59793
# Queue 1041 | Crawled  128
#
# Queue 1041 | Crawled  128
# HTTP Error 404: Not Found
# Thread-22 now crawling https://www.bernama.com/en/search.php?terms=+manifesto&submit=cari
# Queue 1040 | Crawled  129
# HTTP Error 404: Not Found
# Thread-23 now crawling https://www.bernama.com/en/worldlist.php
# Queue 1039 | Crawled  130
# HTTP Error 404: Not Found
# Thread-23 now crawling https://www.bernama.com/en/news.php?id=2022331
# Queue 1038 | Crawled  131
# Thread-25 now crawling https://www.bernama.com/en/search.php?terms=+covid-19+pneumonia&submit=cari
# Queue 1037 | Crawled  132
# Thread-22 now crawling https://www.bernama.com/en/index.php?page=12
# Queue 1039 | Crawled  133
# Thread-24 now crawling https://www.bernama.com/en/search.php?terms=+mdec&submit=cari
# Queue 1047 | Crawled  134
# Thread-20 now crawling https://www.bernama.com/en/news.php?c=02&id=2022482
# Queue 1046 | Crawled  135
# Thread-23 now crawling https://www.bernama.com/en/search.php?terms=+humanitarian+assistance&submit=cari
# Queue 1050 | Crawled  136
